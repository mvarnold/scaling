# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("data/15zpallagi.csv")
data
# Out:
#         STATEFIPS STATE  zipcode  agi_stub        N1     mars1     MARS2  \
# 0               1    AL        0         1  836320.0  481570.0  109790.0
# 1               1    AL        0         2  494830.0  206630.0  146250.0
# 2               1    AL        0         3  261250.0   80720.0  139280.0
# 3               1    AL        0         4  166690.0   28510.0  124650.0
# 4               1    AL        0         5  212660.0   19520.0  184320.0
# 5               1    AL        0         6   55360.0    2950.0   49260.0
# 6               1    AL    35004         1    1490.0     970.0     230.0
# 7               1    AL    35004         2    1350.0     630.0     360.0
# 8               1    AL    35004         3     970.0     310.0     490.0
# 9               1    AL    35004         4     620.0     110.0     470.0
# 10              1    AL    35004         5     620.0      40.0     560.0
# 11              1    AL    35004         6      60.0       0.0      50.0
# ...

# %%
from uszipcode import ZipcodeSearchEngine
search = ZipcodeSearchEngine()
print(search.by_zipcode("48134"))
# Out:
# {
#     "City": "Flat Rock",
#     "Density": 1194.642857142857,
#     "HouseOfUnits": 8416,
#     "LandArea": 17.92,
#     "Latitude": 42.1088517,
#     "Longitude": -83.2827093,
#     "NEBoundLatitude": 42.15256,
#     "NEBoundLongitude": -83.24155209999998,
#     "Population": 21408,
#     "SWBoundLatitude": 42.075542999999996,
#     "SWBoungLongitude": -83.352542,
#     "State": "MI",
#     "TotalWages": 442205660.0,
#     "WaterArea": 0.45,
#     "Wealthy": 20656.09398355755,
#     "Zipcode": "48134",
#     "ZipcodeType": "Standard"
# }

# %%
zip_lat = [search.by_zipcode("05.f"%(i))['Latitude']for i in data['zipcode'][0:100]if i!=0 if i != 99999]
zip_lon = [search.by_zipcode("05.f"%(i))['Longitude']for i in data['zipcode'][0:100]if i!=0 if i != 99999]

# %%
plt.figure(figsize=(16,10))
plt.plot([i for i in zip_lon],[i for i in zip_lat],'.')
plt.show()
