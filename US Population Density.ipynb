# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
population = pd.read_table("data/census_population/R11791826_SL140.txt",delimiter='\t', encoding='latin-1')

# %%
a = list(population["SE_T002_002"].values)
print(len(a))
a = pd.Series(a)
a=a[a>50000]
print(len(a))
# Out:
# 74001
# 1103

# %%
plt.hist(a.dropna(),log=True,density=True)

plt.show()

# %%
plt.hist(a.dropna(),log=True,density=True)

plt.show()

# %%
import seaborn as sns


kernel_options = ['biw','cos','epa','gau','tri','triw']
for kern in kernel_options:
    ax = sns.kdeplot(a.dropna(), kernel = kern, label = kern, shade = True)

plt.show()

ax = sns.distplot(a.dropna(),bins=500)
ax.set_yscale("log")
ax.set_xscale("log")

plt.show()
# Out:
# /Users/Winston/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
a = list(hospitals["SE_T002_002"].values)
a = np.array(a)
print(np.shape(a))
a.sort()

plt.plot(a,'.')
plt.show()

plt.hist(a.dropna())
plt.show()
# Out:
# (74001,)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-72a54b4a42ee> in <module>()
#       7 plt.show()
#       8
# ----> 9 plt.hist(a.dropna())
#      10 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'dropna'

# %%
print(list(hospitals["SE_T002_002"].values).sort())
# Out:
# None

# %%
# Out:
# 1.png                              Travel time scaling dataset.ipynb
# 15zpallagi_zipadded.csv            US Population Density.ipynb
# 2.png                              Untitled.ipynb
# 3.png                              cleaned facilities-census.ipynb
# 4.png                              cleaned facilities.ipynb
# Figures.aux                        complete-data.xlsx
# Figures.log                        data/
# Figures.out                        facilities.ipynb
# Figures.pdf                        google_maps_travel.ipynb
# Figures.synctex.gz                 hospital_scaling.pdf
# Figures.tex                        random_points.py
# Streamlined_scaling-Copy1.ipynb    random_points_and_area.png
# Streamlined_scaling.ipynb
